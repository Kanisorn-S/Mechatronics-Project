# %%
# Import necessary libraries
import numpy as np
import matplotlib.pyplot as plt
import joblib
from sklearn.linear_model import LinearRegression
import pandas as pd

# %%
# Load the trained model
model = joblib.load('../../model/models/new_linear_regression_model.pkl')
print("Model loaded successfully")
# Out:
# Model loaded successfully

# %%
# Define the world points and camera points
world_points = [
  [400, 130], [528, 130], [656, 130], [784, 130], [912, 130], [1040, 130],
  [400, 258], [528, 258], [656, 258], [784, 258], [912, 258], [1040, 258],
  [400, 386], [528, 386], [656, 386], [784, 386], [912, 386], [1040, 386],
  [400, 514], [528, 514], [656, 514], [784, 514], [912, 514], [1040, 514],
  [400, 642], [528, 642], [656, 642], [784, 642], [912, 642], [1040, 642],
  [400, 770], [528, 770], [656, 770], [784, 770], [912, 770], [1040, 770],
]

cam_points = [
  [415, 380], [370, 380], [325, 380], [280, 382], [236, 383], [190, 385],
  [420, 350], [373, 350], [325, 350], [280, 350], [232, 350], [185, 350],
  [423, 313], [375, 314], [327, 314], [278, 313], [228, 314], [177, 315],
  [430, 274], [379, 274], [327, 275], [275, 275], [223, 275], [170, 275],
  [437, 230], [383, 230], [328, 231], [273, 231], [217, 230], [161, 230],
  [447, 182], [388, 180], [329, 181], [270, 180], [212, 180], [151, 180],
]

worldPoints = np.array(world_points, dtype=np.float32)
imagePoints = np.array(cam_points, dtype=np.float32)

# %%
df = pd.DataFrame(world_points, columns=['x', 'y'])
df['x_image'] = pd.Series(imagePoints[:, 0])
df['y_image'] = pd.Series(imagePoints[:, 1])

# %%
df.head()
# Out:
#      x    y  x_image  y_image
# 0  400  130    415.0    380.0
# 1  528  130    370.0    380.0
# 2  656  130    325.0    380.0
# 3  784  130    280.0    382.0
# 4  912  130    236.0    383.0

# %%
# Plot the points in 3D
fig = plt.figure()
ax = fig.add_subplot(121, projection='3d')
ax.set_title('Relationshiop between X, Y and X_image')
ax.scatter(df['x'], df['y'], df['x_image'], c='r', marker='o')
ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.set_zlabel('X_image')
plt.show()

# %%
# Plot the points in 3D
fig = plt.figure()
ax = fig.add_subplot(121, projection='3d')
ax.set_title('Relationshiop between X, Y and Y_image')
ax.scatter(df['y'], df['x'], df['y_image'], c='b', marker='o')
ax.set_xlabel('Y')
ax.set_ylabel('X')
ax.set_zlabel('Y_image')
plt.show()
